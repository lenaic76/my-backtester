# %%
import sys
sys.path.append("..")

import pandas as pd
import quantstats as qs
from data.loader import download_data, compute_returns
from backtester.engine import Backtester
from backtester.metrics import full_metrics

# %%
data = download_data("AAPL", "2018-01-01", "2024-01-01")
data = compute_returns(data)

bt = Backtester(data, initial_capital=10000)
output = bt.run(window=20)
results = output["results"]

# %%
metrics = output["metrics"]

print("=" * 40)
print("   MÉTRIQUES COMPLÈTES")
print("=" * 40)
for k, v in metrics.items():
    print(f"{k:25} : {v}")
# Out:
# ========================================
#    MÉTRIQUES COMPLÈTES
# ========================================
# CAGR (%)                  : nan
# Sharpe                    : 1.52
# Calmar                    : nan
# Max Drawdown (%)          : -22.47
# Win Rate (%)              : 54.64
# Profit Factor             : 1.4
# VaR 95% (%)               : -1.88
# Capital final (€)         : 56486.25
# Nb jours tradés           : 949

# %%
import os

# Affiche le chemin exact que vous essayez d'atteindre
target = "../reports/tearsheet_AAPL_SMA20.html"
absolute = os.path.abspath(target)
print("Chemin absolu visé :", absolute)
print("Le dossier parent existe ?", os.path.exists(os.path.dirname(absolute)))

# Crée le dossier FORCÉMENT
os.makedirs(os.path.dirname(absolute), exist_ok=True)
print("Dossier parent maintenant existant :", os.path.exists(os.path.dirname(absolute)))

# %%
# Récupère les rendements de la stratégie
strategy_returns = results["strategy_returns"].dropna()

# Tearsheet complet avec comparaison au S&P 500
qs.reports.html(
    strategy_returns,
    benchmark="SPY",
    output="../reports/tearsheet_AAPL_SMA20.html",
    title="SMA 20 jours — AAPL"
)

print("Tearsheet généré dans reports/tearsheet_AAPL_SMA20.html")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       2 strategy_returns = results["strategy_returns"].dropna()
#       4 # Tearsheet complet avec comparaison au S&P 500
# ----> 5 qs.reports.html(
#       6     strategy_returns,
#       7     benchmark="SPY",
#       8     output="../reports/tearsheet_AAPL_SMA20.html",
#       9     title="SMA 20 jours — AAPL"
#      10 )
#      12 print("Tearsheet généré dans reports/tearsheet_AAPL_SMA20.html")
#
# File ~\anaconda3\Lib\site-packages\quantstats\reports.py:775, in html(returns, benchmark, rf, grayscale, title, output, compounded, periods_per_year, download_filename, figfmt, template_path, match_dates, **kwargs)
#     772     return
#     774 # Write HTML content to specified output file
# --> 775 with open(output, "w", encoding="utf-8") as f:
#     776     f.write(tpl)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../reports/tearsheet_AAPL_SMA20.html'

# %%
# Tu peux aussi appeler chaque métrique séparément
print(f"Sharpe (quantstats)  : {qs.stats.sharpe(strategy_returns):.2f}")
print(f"Sortino              : {qs.stats.sortino(strategy_returns):.2f}")
print(f"Max Drawdown         : {qs.stats.max_drawdown(strategy_returns)*100:.2f}%")
print(f"Volatilité annuelle  : {qs.stats.volatility(strategy_returns)*100:.2f}%")
print(f"CAGR                 : {qs.stats.cagr(strategy_returns)*100:.2f}%")
